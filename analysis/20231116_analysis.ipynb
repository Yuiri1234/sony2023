# %%
import numpy as np
import pandas as pd
import os
import sys
import matplotlib.pyplot as plt
from collections import Counter

sys.path.append('../')

# %%
from configs.config import CONF

# %%
history_df = pd.read_csv(os.path.join(CONF.PATH.OUTPUT, "20231117-022201_comp_default_frcnn_np", "history.csv"))
history_df = pd.read_csv(os.path.join(CONF.PATH.OUTPUT, "20231117-200331_comp_det_resnet_34_np", "history.csv"))
history_df = pd.read_csv(os.path.join(CONF.PATH.OUTPUT, "20231119-235723_comp_det_resnet_18", "history.csv"))
history_df = pd.read_csv(os.path.join(CONF.PATH.OUTPUT, "20231120-000000_comp_det_resnet_18", "history.csv"))
history_df.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/user/Documents/competition/sony2023/analysis/20231116_analysis.ipynb セル 3 line 3
#       <a href='vscode-notebook-cell:/home/user/Documents/competition/sony2023/analysis/20231116_analysis.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> history_df = pd.read_csv(os.path.join(CONF.PATH.OUTPUT, "20231117-022201_comp_default_frcnn_np", "history.csv"))
#       <a href='vscode-notebook-cell:/home/user/Documents/competition/sony2023/analysis/20231116_analysis.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> history_df = pd.read_csv(os.path.join(CONF.PATH.OUTPUT, "20231117-200331_comp_det_resnet_34_np", "history.csv"))
# ...

# %%
plt.figure(figsize=(20, 5))
history_df.plot(x='global_step', y=['loss', 'loss_classifier', 'loss_box_reg', 'loss_objectness', 'loss_rpn_box_reg'], figsize=(20, 5))
plt.title('Losses')
plt.show()
